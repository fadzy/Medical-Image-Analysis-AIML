# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.applications import EfficientNetB0
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings
for dirname, _, filenames in os.walk('/content/drive'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3003.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3004.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3005.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3006.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3007.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3008.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3009.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3010.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3011.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3012.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3013.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3014.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3015.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3016.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3017.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3018.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3019.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3020.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3021.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3022.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3023.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3024.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3025.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3026.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3027.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3028.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3029.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3030.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3031.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3032.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3033.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3034.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3035.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3036.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3037.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3038.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3039.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3040.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3041.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3042.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3043.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3044.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3045.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3046.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3047.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3048.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3049.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3050.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3051.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3052.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3053.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3054.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3055.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3056.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3057.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3058.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3059.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3060.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3061.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3062.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3063.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/1 httpsfigshare.comarticlesdatasetbrain_tumor_dataset1512427/brainTumorDataPublic_22993064/3064.mat
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/2/archive (2).zip
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/2/mri-brain-tumor-classification.ipynb
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2).zip
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/brain-tumor-detection-br35h.ipynb
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/annotations_all.json
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/annotations_test.json
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y701.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y702.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y703.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y704.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y705.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y706.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y707.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y708.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y709.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y710.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y711.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y712.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y713.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y714.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y715.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y716.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y717.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y718.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y719.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y720.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y721.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y722.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y723.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y724.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y725.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y726.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y727.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y728.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y729.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y730.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y731.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y732.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y733.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y734.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y735.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y736.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y737.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y738.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y739.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y740.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y741.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y742.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y743.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y744.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y745.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y746.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y747.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y748.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y749.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y750.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y751.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y752.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y753.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y754.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y755.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y756.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y757.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y758.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y759.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y760.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y761.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y762.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y763.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y764.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y765.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y766.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y767.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y768.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y769.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y770.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y771.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y772.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y773.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y774.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y775.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y776.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y777.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y778.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y779.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y780.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y781.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y782.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y783.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y784.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y785.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y786.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y787.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y788.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y789.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y790.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y791.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y792.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y793.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y794.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y795.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y796.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y797.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y798.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y799.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TEST/y800.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/annotations_train.json
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y0.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y1.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y10.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y100.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y101.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y102.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y103.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y104.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y105.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y106.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y107.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y108.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y109.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y11.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y110.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y111.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y112.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y113.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y114.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y115.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y116.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y117.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y118.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y119.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y12.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y120.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y121.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y122.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y123.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y124.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y125.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y126.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y127.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y128.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y129.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y13.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y130.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y131.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y132.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y133.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y134.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y135.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y136.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y137.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y138.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y139.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y14.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y140.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y141.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y142.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y143.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y144.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y145.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y146.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y147.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y148.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y149.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y15.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y150.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y151.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y152.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y153.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y154.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y155.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y156.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y157.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y158.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y159.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y16.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y160.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y161.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y162.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y163.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y164.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y165.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y166.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y167.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y168.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y169.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y17.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y170.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y171.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y172.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y173.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y174.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y175.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y176.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y177.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y178.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y179.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y18.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y180.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y181.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y182.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y183.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y184.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y185.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y186.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y187.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y188.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y189.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y19.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y190.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y191.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y192.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y193.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y194.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y195.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y196.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y197.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y198.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y199.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y2.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y20.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y200.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y201.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y202.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y203.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y204.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y205.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y206.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y207.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y208.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y209.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y21.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y210.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y211.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y212.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y213.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y214.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y215.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y216.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y217.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y218.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y219.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y22.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y220.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y221.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y222.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y223.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y224.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y225.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y226.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y227.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y228.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y229.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y23.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y230.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y231.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y232.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y233.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y234.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y235.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y236.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y237.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y238.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y239.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y24.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y240.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y241.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y242.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y243.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y244.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y245.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y246.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y247.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y248.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y249.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y25.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y250.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y251.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y252.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y253.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y254.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y255.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y256.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y257.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y258.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y259.jpg
# /content/drive/MyDrive/Colab Notebooks/dataset/code and dataset for paper improved/3/archive (2)/Br35H-Mask-RCNN/TRAIN/y26.jpg
# ...
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/printsupport/windowsprintersupport.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/platforms/qwebgl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/platforms/qminimal.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/platforms/qwindows.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/platforms/qoffscreen.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/install_plugins/install/repository_adapter/online_product_impl/libmwonlineproductrepoadapterimpl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/install_plugins/install/repository_adapter/folder_impl/libmwfolderrepoadapterimpl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/silentlauncher/framework/launcherimpl/libmwsilentlauncher.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/mf0/install/datamodels/transitive_closure/mwinstall_datamodels_transitive_closure_ms_gen.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/mf0/install/datamodels/common/mwinstall_datamodels_common_ms_gen.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/mf0/install/datamodels/product_installer/mwinstall_datamodels_product_installer_ms_gen.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/mf0/install/datamodels/product_update/mwinstall_datamodels_product_update_ms_gen.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/mf0/install/datamodels/activation/mwinstall_datamodels_activation_ms_gen.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/mf0/install/datamodels/login/mwinstall_datamodels_login_ms_gen.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/mf0/mf0_json/mwmf0_json_app.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/mf0/mf0/mwmf0_ms_gen.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/mf0/mf0/mwmf0_app.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/styles/qwindowsvistastyle.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/imageformats/qjpeg.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/imageformats/qgif.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/imageformats/qicns.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/imageformats/qico.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/imageformats/qsvg.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/imageformats/qwbmp.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/imageformats/qwebp.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/imageformats/qtiff.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/imageformats/qtga.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/foundation/urlmanager/foundation/urlmanager/impl/mwurlmanagerimpl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/foundation/httpproxy/foundation/httpproxy/implementation/mwhttpproxy_implementation.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/foundation/httpclient/foundation/httpclient_core/libcurlinitializer/implementation/mwlibcurlinitializer_impl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/foundation/httpclient/foundation/httpclient_core/implementation/mwhttpclient_core_implementation.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/iconengines/qsvgicon.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/security/libmwconnectorsecurityactivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/message_service/libmwconnectormessageserviceactivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/http/libmwconnectorhttpactivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/json/libmwconnectorjsonactivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/hitchhiker/libmwconnectorhitchhikeractivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/common_services/libmwconnectorcommonservicesactivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/configuration/libmwconnectorconfigurationactivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/framework/libmwconnectorframeworkactivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/bayeux/libmwconnectorbayeuxactivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/container/libmwconnectorcontaineractivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/binary/libmwconnectorbinaryactivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/connector/administration/libmwconnectoradministrationactivator.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_plugins/editorservices/clipboardservice/mwservice.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/dialogs/foundation/platform/libmwplatformdialogs.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppmicroservices_compendium/foundation/cppmicroservices/logserviceimpl/mwLogServiceImpl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/connector_bootstrap_plugins/connector/connector_impl/libmwconnectorconnectorimpl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/httpproxy_implementation.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/libcurlinitializer_impl.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/httpclient_core_implementation.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/PlatformDialogs.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/libmwfoundation_feature_fctrl.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/mf0_ms_gen.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/mf0_app.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/activationwsserviceimpl.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/mf0_json_app.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/install_datamodels_transitive_closure_ms_gen.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/cefcommon_fctrl.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/install_datamodels_login_ms_gen.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/install_datamodels_common_ms_gen.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/install_datamodels_activation_ms_gen.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/install_datamodels_product_installer_ms_gen.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/install_datamodels_product_update_ms_gen.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/onlineproductrepoadapterimpl.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cppms_cache_manifests/folderrepoadapterimpl.bpf
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/ddux/ddux_logging/ddux_logging/mwddux_logging.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/fctrl_ext/foundation/feature/mwlibmwfoundation_feature_fctrl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/fctrl_ext/cefclient_browser/mwcefcommon_fctrl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_services/cefclient_interface/mwwebwindowmanager_extprocess_impl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_resources/chrome_200_percent.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_resources/chrome_100_percent.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_resources/resources.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/el.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/am.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/es-419.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/bn.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/ca.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/cs.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/en-GB.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/de.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/bg.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/da.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/ar.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/en-US.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/hi.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/it.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/es.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/ko.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/id.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/he.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/lt.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/ja.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/et.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/kn.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/fa.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/fil.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/fi.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/fr.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/hr.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/gu.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/hu.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/mr.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/lv.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/sk.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/sr.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/nb.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/ro.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/pt-BR.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/ml.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/sl.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/ru.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/ms.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/pt-PT.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/nl.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/pl.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/zh-TW.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/tr.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/te.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/vi.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/th.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/sv.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/zh-CN.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/uk.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/ta.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/cef_locales/sw.pak
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/win64/activation/install/activationwsclient/mwactivationwsserviceimpl.dll
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/icutzdata/metaZones.res
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/icutzdata/windowsZones.res
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/icutzdata/zoneinfo64.res
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/bin/icutzdata/timezoneTypes.res
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/archives/win64/Uninstaller221_win64.zip
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/archives/win64/Network_License_Manager111621_win64.zip
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/archives/common/Network_License_Manager111621_common.zip
# /content/drive/MyDrive/Downloads/_temp_matlab_R2022b_win64/archives/common/Uninstaller221_common.zip
# /content/drive/MyDrive/Downloads/.ipynb_checkpoints/ml project using decision tree (1)-checkpoint.ipynb
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/LICENSE
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/metacritic_critic_reviews.csv
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/review_sentiment1.py
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/reviews_sentiment.csv
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/.idea/sentiment_analysis-main.iml
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/.idea/misc.xml
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/.idea/modules.xml
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/.idea/.gitignore
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/.idea/.name
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/.idea/workspace.xml
# /content/drive/MyDrive/Downloads/sentiment_analysis-main/sentiment_analysis-main/.idea/inspectionProfiles/profiles_settings.xml

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

sns.palplot(colors_dark)
sns.palplot(colors_green)
sns.palplot(colors_red)

# %%
labels = ['glioma','notumor','meningioma','pituitary']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/Othercomputers/My Laptop/M.tech thesis Sept2023/large4c7023images/Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join('/content/drive/Othercomputers/My Laptop/M.tech thesis Sept2023/large4c7023images/Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 1321/1321 [00:07<00:00, 187.74it/s]
# 100%|██████████| 1595/1595 [00:07<00:00, 214.00it/s]
# 100%|██████████| 1339/1339 [00:07<00:00, 176.96it/s]
# 100%|██████████| 1457/1457 [00:09<00:00, 161.07it/s]
# 100%|██████████| 300/300 [00:01<00:00, 213.43it/s]
# 100%|██████████| 405/405 [00:01<00:00, 265.96it/s]
# 100%|██████████| 306/306 [00:01<00:00, 221.42it/s]
# 100%|██████████| 300/300 [00:01<00:00, 200.00it/s]

# %%
k=0
fig, ax = plt.subplots(1,4,figsize=(15,15))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train.shape
# Out:
# (7023, 224, 224, 3)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.2,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 224, 224, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 225, 225, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 112, 112, 32)         864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 112, 112, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 112, 112, 32)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 112, 112, 32)         288       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 112, 112, 32)         128       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 112, 112, 32)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 32)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 112, 112, 32)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 112, 112, 16)         512       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 112, 112, 16)         64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block2a_expand_conv (Conv2  (None, 112, 112, 96)         1536      ['block1a_project_bn[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 112, 112, 96)         384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 112, 112, 96)         0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 113, 113, 96)         0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 56, 56, 96)           864       ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 56, 56, 96)           384       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 56, 56, 96)           0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 96)                   0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 96)             0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 4)              388       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 96)             480       ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 56, 56, 96)           0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 56, 56, 24)           2304      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 56, 56, 24)           96        ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 56, 56, 144)          3456      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 56, 56, 144)          576       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 56, 56, 144)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 56, 56, 144)          1296      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 56, 56, 144)          576       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 56, 56, 144)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 144)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 56, 56, 144)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 56, 56, 24)           3456      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 56, 56, 24)           96        ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 56, 56, 24)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 56, 56, 24)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 56, 56, 144)          3456      ['block2b_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 56, 56, 144)          576       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 56, 56, 144)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 59, 59, 144)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 28, 28, 144)          3600      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 28, 28, 144)          576       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 28, 28, 144)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 144)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 28, 28, 144)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 28, 28, 40)           5760      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 28, 28, 40)           160       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 28, 28, 240)          9600      ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 28, 28, 240)          960       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 28, 28, 240)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 28, 28, 240)          6000      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 28, 28, 240)          960       ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 28, 28, 240)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 240)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 28, 28, 240)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 28, 28, 40)           9600      ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 28, 28, 40)           160       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 28, 28, 40)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 28, 28, 40)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 28, 28, 240)          9600      ['block3b_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 28, 28, 240)          960       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 28, 28, 240)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 29, 29, 240)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 14, 14, 240)          2160      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 14, 14, 240)          960       ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 14, 14, 240)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 240)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 14, 14, 240)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 14, 14, 80)           19200     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 14, 14, 80)           320       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 14, 14, 480)          38400     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 14, 14, 480)          1920      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 14, 14, 480)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 14, 14, 480)          4320      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 14, 14, 480)          1920      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 14, 14, 480)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 480)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 14, 14, 480)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 14, 14, 80)           38400     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 14, 14, 80)           320       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 14, 14, 80)           0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 14, 14, 80)           0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 14, 14, 480)          38400     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 14, 14, 480)          1920      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 14, 14, 480)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 14, 14, 480)          4320      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 14, 14, 480)          1920      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 14, 14, 480)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 480)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 14, 14, 480)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 14, 14, 80)           38400     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 14, 14, 80)           320       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 14, 14, 80)           0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 14, 14, 80)           0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 14, 14, 480)          38400     ['block4c_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 14, 14, 480)          1920      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 14, 14, 480)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv (DepthwiseC  (None, 14, 14, 480)          12000     ['block5a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5a_bn (BatchNormaliza  (None, 14, 14, 480)          1920      ['block5a_dwconv[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 14, 14, 480)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 480)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 14, 14, 480)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 14, 14, 112)          53760     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 14, 14, 112)          448       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 14, 14, 672)          75264     ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 14, 14, 672)          2688      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 14, 14, 672)          0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv (DepthwiseC  (None, 14, 14, 672)          16800     ['block5b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5b_bn (BatchNormaliza  (None, 14, 14, 672)          2688      ['block5b_dwconv[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 14, 14, 672)          0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 672)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 14, 14, 672)          0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 14, 14, 112)          75264     ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 14, 14, 112)          448       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 14, 14, 112)          0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 14, 14, 112)          0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 14, 14, 672)          75264     ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 14, 14, 672)          2688      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 14, 14, 672)          0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv (DepthwiseC  (None, 14, 14, 672)          16800     ['block5c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5c_bn (BatchNormaliza  (None, 14, 14, 672)          2688      ['block5c_dwconv[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 14, 14, 672)          0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 672)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 14, 14, 672)          0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 14, 14, 112)          75264     ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 14, 14, 112)          448       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 14, 14, 112)          0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 14, 14, 112)          0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2  (None, 14, 14, 672)          75264     ['block5c_add[0][0]']
#  D)
#
#  block6a_expand_bn (BatchNo  (None, 14, 14, 672)          2688      ['block6a_expand_conv[0][0]']
#  rmalization)
#
#  block6a_expand_activation   (None, 14, 14, 672)          0         ['block6a_expand_bn[0][0]']
#  (Activation)
#
#  block6a_dwconv_pad (ZeroPa  (None, 17, 17, 672)          0         ['block6a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block6a_dwconv (DepthwiseC  (None, 7, 7, 672)            16800     ['block6a_dwconv_pad[0][0]']
#  onv2D)
#
#  block6a_bn (BatchNormaliza  (None, 7, 7, 672)            2688      ['block6a_dwconv[0][0]']
#  tion)
#
#  block6a_activation (Activa  (None, 7, 7, 672)            0         ['block6a_bn[0][0]']
#  tion)
#
#  block6a_se_squeeze (Global  (None, 672)                  0         ['block6a_activation[0][0]']
#  AveragePooling2D)
#
# ...
#  block6b_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6b_se_squeeze[0][0]']
#  e)
#
#  block6b_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multipl  (None, 7, 7, 1152)           0         ['block6b_activation[0][0]',
#  y)                                                                  'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv  (None, 7, 7, 192)            221184    ['block6b_se_excite[0][0]']
#  2D)
#
#  block6b_project_bn (BatchN  (None, 7, 7, 192)            768       ['block6b_project_conv[0][0]']
#  ormalization)
#
#  block6b_drop (Dropout)      (None, 7, 7, 192)            0         ['block6b_project_bn[0][0]']
#
#  block6b_add (Add)           (None, 7, 7, 192)            0         ['block6b_drop[0][0]',
#                                                                      'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2  (None, 7, 7, 1152)           221184    ['block6b_add[0][0]']
#  D)
#
#  block6c_expand_bn (BatchNo  (None, 7, 7, 1152)           4608      ['block6c_expand_conv[0][0]']
#  rmalization)
#
#  block6c_expand_activation   (None, 7, 7, 1152)           0         ['block6c_expand_bn[0][0]']
#  (Activation)
#
#  block6c_dwconv (DepthwiseC  (None, 7, 7, 1152)           28800     ['block6c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6c_bn (BatchNormaliza  (None, 7, 7, 1152)           4608      ['block6c_dwconv[0][0]']
#  tion)
#
#  block6c_activation (Activa  (None, 7, 7, 1152)           0         ['block6c_bn[0][0]']
#  tion)
#
#  block6c_se_squeeze (Global  (None, 1152)                 0         ['block6c_activation[0][0]']
#  AveragePooling2D)
#
#  block6c_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6c_se_squeeze[0][0]']
#  e)
#
#  block6c_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multipl  (None, 7, 7, 1152)           0         ['block6c_activation[0][0]',
#  y)                                                                  'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv  (None, 7, 7, 192)            221184    ['block6c_se_excite[0][0]']
#  2D)
#
#  block6c_project_bn (BatchN  (None, 7, 7, 192)            768       ['block6c_project_conv[0][0]']
#  ormalization)
#
#  block6c_drop (Dropout)      (None, 7, 7, 192)            0         ['block6c_project_bn[0][0]']
#
#  block6c_add (Add)           (None, 7, 7, 192)            0         ['block6c_drop[0][0]',
#                                                                      'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2  (None, 7, 7, 1152)           221184    ['block6c_add[0][0]']
#  D)
#
#  block6d_expand_bn (BatchNo  (None, 7, 7, 1152)           4608      ['block6d_expand_conv[0][0]']
#  rmalization)
#
#  block6d_expand_activation   (None, 7, 7, 1152)           0         ['block6d_expand_bn[0][0]']
#  (Activation)
#
#  block6d_dwconv (DepthwiseC  (None, 7, 7, 1152)           28800     ['block6d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6d_bn (BatchNormaliza  (None, 7, 7, 1152)           4608      ['block6d_dwconv[0][0]']
#  tion)
#
#  block6d_activation (Activa  (None, 7, 7, 1152)           0         ['block6d_bn[0][0]']
#  tion)
#
#  block6d_se_squeeze (Global  (None, 1152)                 0         ['block6d_activation[0][0]']
#  AveragePooling2D)
#
#  block6d_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6d_se_squeeze[0][0]']
#  e)
#
#  block6d_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multipl  (None, 7, 7, 1152)           0         ['block6d_activation[0][0]',
#  y)                                                                  'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv  (None, 7, 7, 192)            221184    ['block6d_se_excite[0][0]']
#  2D)
#
#  block6d_project_bn (BatchN  (None, 7, 7, 192)            768       ['block6d_project_conv[0][0]']
#  ormalization)
#
#  block6d_drop (Dropout)      (None, 7, 7, 192)            0         ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)           (None, 7, 7, 192)            0         ['block6d_drop[0][0]',
#                                                                      'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 7, 7, 1152)           221184    ['block6d_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 7, 7, 1152)           4608      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 7, 7, 1152)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 7, 7, 1152)           10368     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 7, 7, 1152)           4608      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 7, 7, 1152)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1152)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 7, 7, 1152)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 7, 7, 320)            368640    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 7, 7, 320)            1280      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  top_conv (Conv2D)           (None, 7, 7, 1280)           409600    ['block7a_project_bn[0][0]']
#
#  top_bn (BatchNormalization  (None, 7, 7, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 7, 7, 1280)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 1280)                 0         ['top_activation[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 4)                    5124      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 4054695 (15.47 MB)
# Trainable params: 4012672 (15.31 MB)
# Non-trainable params: 42023 (164.16 KB)
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =15, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/15
# 158/158 [==============================] - ETA: 0s - loss: 0.2432 - accuracy: 0.9153
# Epoch 1: val_accuracy improved from -inf to 0.89680, saving model to effnet.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 158/158 [==============================] - 93s 290ms/step - loss: 0.2432 - accuracy: 0.9153 - val_loss: 0.3792 - val_accuracy: 0.8968 - lr: 0.0010
# Epoch 2/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9686
# Epoch 2: val_accuracy improved from 0.89680 to 0.93594, saving model to effnet.h5
# 158/158 [==============================] - 43s 270ms/step - loss: 0.0940 - accuracy: 0.9686 - val_loss: 0.2198 - val_accuracy: 0.9359 - lr: 0.0010
# Epoch 3/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9778
# Epoch 3: val_accuracy improved from 0.93594 to 0.98043, saving model to effnet.h5
# 158/158 [==============================] - 43s 273ms/step - loss: 0.0690 - accuracy: 0.9778 - val_loss: 0.0600 - val_accuracy: 0.9804 - lr: 0.0010
# Epoch 4/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9828
# Epoch 4: val_accuracy did not improve from 0.98043
# 158/158 [==============================] - 42s 269ms/step - loss: 0.0540 - accuracy: 0.9828 - val_loss: 0.2201 - val_accuracy: 0.9484 - lr: 0.0010
# Epoch 5/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9881
# Epoch 5: val_accuracy did not improve from 0.98043
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 158/158 [==============================] - 42s 269ms/step - loss: 0.0370 - accuracy: 0.9881 - val_loss: 0.0803 - val_accuracy: 0.9733 - lr: 0.0010
# Epoch 6/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9945
# Epoch 6: val_accuracy improved from 0.98043 to 0.99466, saving model to effnet.h5
# 158/158 [==============================] - 43s 272ms/step - loss: 0.0148 - accuracy: 0.9945 - val_loss: 0.0289 - val_accuracy: 0.9947 - lr: 3.0000e-04
# Epoch 7/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9986
# Epoch 7: val_accuracy did not improve from 0.99466
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0248 - val_accuracy: 0.9929 - lr: 3.0000e-04
# Epoch 8/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9992
# Epoch 8: val_accuracy improved from 0.99466 to 0.99644, saving model to effnet.h5
# 158/158 [==============================] - 43s 274ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0177 - val_accuracy: 0.9964 - lr: 3.0000e-04
# Epoch 9/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9990
# Epoch 9: val_accuracy did not improve from 0.99644
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0328 - val_accuracy: 0.9875 - lr: 3.0000e-04
# Epoch 10/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992
# Epoch 10: val_accuracy did not improve from 0.99644
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0207 - val_accuracy: 0.9947 - lr: 3.0000e-04
# Epoch 11/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 11: val_accuracy did not improve from 0.99644
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0207 - val_accuracy: 0.9947 - lr: 9.0000e-05
# Epoch 12/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 12: val_accuracy did not improve from 0.99644
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0207 - val_accuracy: 0.9947 - lr: 9.0000e-05
# Epoch 13/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 13: val_accuracy did not improve from 0.99644
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0224 - val_accuracy: 0.9947 - lr: 2.7000e-05
# Epoch 14/15
# 158/158 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9996
# Epoch 14: val_accuracy did not improve from 0.99644
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0200 - val_accuracy: 0.9947 - lr: 2.7000e-05
# Epoch 15/15
# 158/158 [==============================] - ETA: 0s - loss: 9.6067e-04 - accuracy: 0.9998
# Epoch 15: val_accuracy did not improve from 0.99644
# 158/158 [==============================] - 42s 269ms/step - loss: 9.6067e-04 - accuracy: 0.9998 - val_loss: 0.0202 - val_accuracy: 0.9947 - lr: 8.1000e-06

# %%
filterwarnings('ignore')

epochs = [i for i in range(15)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label ='Training Loss')
ax[1].plot(epochs, val_loss, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 44/44 [==============================] - 3s 59ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       348
#            1       1.00      1.00      1.00       398
#            2       0.99      0.99      0.99       342
#            3       0.99      0.99      0.99       317
#
#     accuracy                           1.00      1405
#    macro avg       1.00      1.00      1.00      1405
# weighted avg       1.00      1.00      1.00      1405

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 7))

# Create a custom format function to display only whole numbers
def format_func(value):
    return f'{value:.0f}'  # This format will display whole numbers

sns.heatmap(confusion_matrix(y_test_new, pred), ax=ax, xticklabels=labels, yticklabels=labels, annot=True,
           fmt='d', cmap=colors_green[::-1], alpha=0.7, linewidths=2, linecolor=colors_dark[3])

fig.text(s='Heatmap of the Confusion Matrix', size=18, fontweight='bold',
         fontname='monospace', color=colors_dark[1], y=0.92, x=0.28, alpha=0.8)

plt.show()

# %%
def img_pred(upload):
    for name, file_info in uploader.value.items():
        img = Image.open(io.BytesIO(file_info['content']))
    opencvImage = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    img = cv2.resize(opencvImage,(224,224))
    img = img.reshape(1,224,224,3)
    p = model.predict(img)
    p = np.argmax(p,axis=1)[0]

    if p==0:
        p='Glioma Tumor'
    elif p==1:
        print('The model predicts that there is no tumor')
    elif p==2:
        p='Meningioma Tumor'
    else:
        p='Pituitary Tumor'

    if p!=1:
        print(f'The Model predicts that it is a {p}')

# %%
uploader = widgets.FileUpload()
display(uploader)
# Out:
# FileUpload(value={}, description='Upload')

# %%
button = widgets.Button(description='Predict')
out = widgets.Output()
def on_button_clicked(_):
    with out:
        clear_output()
        try:
            img_pred(uploader)

        except:
            print('No Image Uploaded/Invalid Image File')
button.on_click(on_button_clicked)
widgets.VBox([button,out])
# Out:
# VBox(children=(Button(description='Predict', style=ButtonStyle()), Output()))
